# %%
import pandas as pd
import folium

# Load the CSV file into a DataFrame
file_path = 'EchoPulse_List.csv'  # Update with your file path
data = pd.read_csv(file_path)

# Ensure 'recordedAt' column is in datetime format
data['recordedAt'] = pd.to_datetime(data['recordedAt'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Check if data contains 'latitude' and 'longitude' columns
if 'latitude' not in data.columns or 'longitude' not in data.columns:
    print("Error: The CSV file doesn't contain 'latitude' and 'longitude' columns.")
else:
    # Step 1: Create a folium map
    # Center the map at the first row's latitude and longitude
    map_center = [data['latitude'].iloc[0], data['longitude'].iloc[0]]
    m = folium.Map(location=map_center, zoom_start=12)

    # Step 2: Add markers for each data point
    for idx, row in data.iterrows():
        folium.Marker([row['latitude'], row['longitude']],
                      popup=f"Time: {row['recordedAt']}").add_to(m)

    # Step 3: Display the map in Jupyter notebook
    from IPython.display import display
    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_314f5674d8b64d4cb90883af2f33bc5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_314f5674d8b64d4cb90883af2f33bc5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_314f5674d8b64d4cb90883af2f33bc5d = L.map(
#                 &quot;map_314f5674d8b64d4cb90883af2f33bc5d&quot;,
#                 {
#                     center: [13.11631070320018, 77.62485343891188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a064b937c0952c23b1d1810e9236ff5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a064b937c0952c23b1d1810e9236ff5f.addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#             var marker_11e17ec3ac869d2ab42699d95356852c = L.marker(
#                 [13.11631070320018, 77.62485343891188],
#                 {}
#             ).addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#         var popup_c60c31cda6a22c2d23ed594f4df31e2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da9686248d2719dcc34bf0ecc9d46848 = $(`&lt;div id=&quot;html_da9686248d2719dcc34bf0ecc9d46848&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:40:44.918000&lt;/div&gt;`)[0];
#                 popup_c60c31cda6a22c2d23ed594f4df31e2d.setContent(html_da9686248d2719dcc34bf0ecc9d46848);
#
#
#
#         marker_11e17ec3ac869d2ab42699d95356852c.bindPopup(popup_c60c31cda6a22c2d23ed594f4df31e2d)
#         ;
#
#
#
#
#             var marker_6f920bacbe5a33f29a206aa8298254c6 = L.marker(
#                 [13.116596732959088, 77.62522721075622],
#                 {}
#             ).addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#         var popup_e76c99e76f56c269094510131f50b5f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f95b01ea31851224af65b981dbac8941 = $(`&lt;div id=&quot;html_f95b01ea31851224af65b981dbac8941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:40:54.926000&lt;/div&gt;`)[0];
#                 popup_e76c99e76f56c269094510131f50b5f0.setContent(html_f95b01ea31851224af65b981dbac8941);
#
#
#
#         marker_6f920bacbe5a33f29a206aa8298254c6.bindPopup(popup_e76c99e76f56c269094510131f50b5f0)
#         ;
#
#
#
#
#             var marker_cce5951943c732bf1ca7ae470aecf6fa = L.marker(
#                 [13.117367392580835, 77.62519803130562],
#                 {}
#             ).addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#         var popup_9a24e3abc6b7518b1877859c51d53cac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ddc578e1611fa3f6d35c73a56b7fa23 = $(`&lt;div id=&quot;html_0ddc578e1611fa3f6d35c73a56b7fa23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:41:28.748000&lt;/div&gt;`)[0];
#                 popup_9a24e3abc6b7518b1877859c51d53cac.setContent(html_0ddc578e1611fa3f6d35c73a56b7fa23);
#
#
#
#         marker_cce5951943c732bf1ca7ae470aecf6fa.bindPopup(popup_9a24e3abc6b7518b1877859c51d53cac)
#         ;
#
#
#
#
#             var marker_fc0f74696dc34c661266390ea6cf729b = L.marker(
#                 [13.121651099845357, 77.62587184161349],
#                 {}
#             ).addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#         var popup_be03724ec6932d9cfdb2319d13ad3600 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f8aaa082d62175a674b5222e5493ab2 = $(`&lt;div id=&quot;html_3f8aaa082d62175a674b5222e5493ab2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:43:06.229000&lt;/div&gt;`)[0];
#                 popup_be03724ec6932d9cfdb2319d13ad3600.setContent(html_3f8aaa082d62175a674b5222e5493ab2);
#
#
#
#         marker_fc0f74696dc34c661266390ea6cf729b.bindPopup(popup_be03724ec6932d9cfdb2319d13ad3600)
#         ;
#
#
#
#
#             var marker_b060c87a03e7c70edf648a5a01c448af = L.marker(
#                 [13.11460218947422, 77.6237676082888],
#                 {}
#             ).addTo(map_314f5674d8b64d4cb90883af2f33bc5d);
#
#
#         var popup_4c06fba21bb17c0b3c88832121bbd7e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c38a962f1f314391b79a3cbcf7446f0b = $(`&lt;div id=&quot;html_c38a962f1f314391b79a3cbcf7446f0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:43:27.548000&lt;/div&gt;`)[0];
#                 popup_4c06fba21bb17c0b3c88832121bbd7e9.setContent(html_c38a962f1f314391b79a3cbcf7446f0b);
#
#
#
#         marker_b060c87a03e7c70edf648a5a01c448af.bindPopup(popup_4c06fba21bb17c0b3c88832121bbd7e9)
#         ;

# %%
import pandas as pd
import folium
from IPython.display import display

# Load the CSV file into a DataFrame
file_path = 'EchoPulse_List.csv'  # Update with your file path
data = pd.read_csv(file_path, ob_bad_lines='skip')

# Ensure 'recordedAt' column is in datetime format
data['recordedAt'] = pd.to_datetime(data['recordedAt'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Filter data for 'Moving' activity
moving_data = data[data['activity'] == 'Moving']

# Check if there are any 'Moving' points
if moving_data.empty:
    print("No 'Moving' activity points found in the data.")
else:
    # Step 1: Create a folium map
    # Center the map at the first 'Moving' row's latitude and longitude
    map_center = [moving_data['latitude'].iloc[0], moving_data['longitude'].iloc[0]]
    m = folium.Map(location=map_center, zoom_start=12)

    # Step 2: Add markers for each 'Moving' data point
    for idx, row in moving_data.iterrows():
        folium.Marker(
            [row['latitude'], row['longitude']],
            popup=f"Time: {row['recordedAt']}"
        ).add_to(m)

    # Step 3: Display the map in Jupyter notebook
    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24b4627978fe6e789e57a84b1f2e7dac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24b4627978fe6e789e57a84b1f2e7dac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24b4627978fe6e789e57a84b1f2e7dac = L.map(
#                 &quot;map_24b4627978fe6e789e57a84b1f2e7dac&quot;,
#                 {
#                     center: [13.11631070320018, 77.62485343891188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1bd272e3448ef64415aca45ddce18de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a1bd272e3448ef64415aca45ddce18de.addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#             var marker_4f4c02b5c426624fa3dbe0b56297ce8a = L.marker(
#                 [13.11631070320018, 77.62485343891188],
#                 {}
#             ).addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#         var popup_3e15c19689034683d1ed6955c8ff45a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6b564bc0f98f49b532d7ef29c61f200 = $(`&lt;div id=&quot;html_b6b564bc0f98f49b532d7ef29c61f200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:40:44.918000&lt;/div&gt;`)[0];
#                 popup_3e15c19689034683d1ed6955c8ff45a8.setContent(html_b6b564bc0f98f49b532d7ef29c61f200);
#
#
#
#         marker_4f4c02b5c426624fa3dbe0b56297ce8a.bindPopup(popup_3e15c19689034683d1ed6955c8ff45a8)
#         ;
#
#
#
#
#             var marker_e60a4a4fdf5186688c98c99de5cc1382 = L.marker(
#                 [13.116596732959088, 77.62522721075622],
#                 {}
#             ).addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#         var popup_6fcce925b7eb62013dd58ec5ecc83702 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65483b070fb3965da55010d315e522ab = $(`&lt;div id=&quot;html_65483b070fb3965da55010d315e522ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:40:54.926000&lt;/div&gt;`)[0];
#                 popup_6fcce925b7eb62013dd58ec5ecc83702.setContent(html_65483b070fb3965da55010d315e522ab);
#
#
#
#         marker_e60a4a4fdf5186688c98c99de5cc1382.bindPopup(popup_6fcce925b7eb62013dd58ec5ecc83702)
#         ;
#
#
#
#
#             var marker_dff404165582d5c59f71fd3c49861a73 = L.marker(
#                 [13.117367392580835, 77.62519803130562],
#                 {}
#             ).addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#         var popup_faa4e139bce15c17c71967f5eac1b32d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1153682b6f5ca4f062769c3e49804edc = $(`&lt;div id=&quot;html_1153682b6f5ca4f062769c3e49804edc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:41:28.748000&lt;/div&gt;`)[0];
#                 popup_faa4e139bce15c17c71967f5eac1b32d.setContent(html_1153682b6f5ca4f062769c3e49804edc);
#
#
#
#         marker_dff404165582d5c59f71fd3c49861a73.bindPopup(popup_faa4e139bce15c17c71967f5eac1b32d)
#         ;
#
#
#
#
#             var marker_8127be215b2fbcd3b704ebfebdc91a87 = L.marker(
#                 [13.121651099845357, 77.62587184161349],
#                 {}
#             ).addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#         var popup_b017e8c19ab491cad81948e63d0a574b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_670675cb63ad35c34064f34c1134dd37 = $(`&lt;div id=&quot;html_670675cb63ad35c34064f34c1134dd37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:43:06.229000&lt;/div&gt;`)[0];
#                 popup_b017e8c19ab491cad81948e63d0a574b.setContent(html_670675cb63ad35c34064f34c1134dd37);
#
#
#
#         marker_8127be215b2fbcd3b704ebfebdc91a87.bindPopup(popup_b017e8c19ab491cad81948e63d0a574b)
#         ;
#
#
#
#
#             var marker_b853378e95217ff6c2a31cb5ba7eadf5 = L.marker(
#                 [13.12181601412684, 77.62509596138518],
#                 {}
#             ).addTo(map_24b4627978fe6e789e57a84b1f2e7dac);
#
#
#         var popup_e7e18a2cd9f6d3b475a1dda90fe8fc40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f332dd185fe939cb75698226fd4c3477 = $(`&lt;div id=&quot;html_f332dd185fe939cb75698226fd4c3477&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time: 2025-01-17 06:43:28.987000&lt;/div&gt;`)[0];
#                 popup_e7e18a2cd9f6d3b475a1dda90fe8fc40.setContent(html_f332dd185fe939cb75698226fd4c3477);
#
#
#
#         marker_b853378e95217ff6c2a31cb5ba7eadf5.bindPopup(popup_e7e18a2cd9f6d3b475a1dda90fe8fc40)
#         ;
